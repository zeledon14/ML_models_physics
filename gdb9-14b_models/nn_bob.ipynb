# %%
import numpy as np
import tensorflow as tf
from sklearn import preprocessing
import re
import os
import matplotlib.pyplot as plt
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
numb_feat='484'
exp_name='int_E_T_298_och_1'
feat_type='bob'
enert= np.load('../../data_features/och_data/internal_energy_T_298_OCH.npy')
G= np.load('../../data_features/och_data/bob_OCH_484.npy')
numb_atoms= np.load('../../data_features/och_data/number_of_atoms_per_structure_OCH.npy')
#enert= enert[:10000]
#G= G[:10000]
#numb_atoms= numb_atoms[:10000]
Et= np.squeeze(enert)
g_st= preprocessing.MaxAbsScaler().fit_transform(G)
print '*********************'
print 'g_st ', g_st.shape
print 'enert ', enert.shape
np.save('g_scaled_%s_%s_%s'%(feat_type,numb_feat,exp_name), g_st)
# Out:
# *********************
# g_st  (50592, 484)
# enert  (50592,)

# %%
G_scaled= g_st
E=np.reshape(enert,(len(enert),1))
print E.shape
print G_scaled.shape

mixer= np.array(range(G_scaled.shape[0]))
for _ in range(10000):
    np.random.shuffle(mixer)
n= int(len(mixer)*0.75) # marking the 90%
G_train_scaled= G_scaled[mixer[:n]]
G_vali_scaled= G_scaled[mixer[n:]]
E_train= E[mixer[:n]]
E_vali= E[mixer[n:]]
trai_id= mixer[:n]
vali_id= mixer[n:]
print 'G_train_scaled->', G_train_scaled.shape
print 'G_vali_scaled->', G_vali_scaled.shape
print 'E_train->', E_train.shape
print 'E_vali->', E_vali.shape
# Out:
# (50592, 1)
# (50592, 484)
# G_train_scaled-> (37944, 484)
# G_vali_scaled-> (12648, 484)
# E_train-> (37944, 1)
# E_vali-> (12648, 1)

# %%
#l= 100
#k= 70
#q= 40
#p= 1

# %%
#l= 20
#k= 20
#q= 1
#p= 1
#t= 50
#w0= tf.get_variable("w0", [G_scaled.shape[1], l], initializer = tf.contrib.layers.xavier_initializer(seed = 1))
#b0= tf.Variable(tf.zeros([1,l]), name= 'b0')
#w1= tf.get_variable("w1", [l, k], initializer = tf.contrib.layers.xavier_initializer(seed = 3))
#b1= tf.Variable(tf.zeros([1,k]), name= 'b1')
#w2= tf.get_variable("w2", [k, q], initializer = tf.contrib.layers.xavier_initializer(seed = 5))
#b2= tf.Variable(tf.zeros([1,q]), name= 'b2')
#w3= tf.get_variable("w3", [q, p], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b3= tf.Variable(tf.zeros([1,p]), name= 'b3')
#w4= tf.get_variable("w4", [p, t], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b4= tf.Variable(tf.zeros([1,t]), name= 'b4')
#w5= tf.get_variable("w5", [t, 1], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b5= tf.Variable(tf.zeros([1,1]), name= 'b5')

# %%
l= 50
k= 30
q= 1
#p= 1
#t= 50
w0= tf.Variable(tf.random_uniform([G_scaled.shape[1], l], -1.0, 1.0), name= 'w0')
b0= tf.Variable(tf.zeros([1,l]), name= 'b0')
w1= tf.Variable(tf.random_uniform([l, k], -1.0, 1.0), name= 'w1')
b1= tf.Variable(tf.zeros([1,k]), name= 'b1')
w2= tf.Variable(tf.random_uniform([k, q], -1.0, 1.0), name= 'w2')
b2= tf.Variable(tf.zeros([1,q]), name= 'b2')
#w3= tf.get_variable("w3", [q, p], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b3= tf.Variable(tf.zeros([1,p]), name= 'b3')
#w4= tf.get_variable("w4", [p, t], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b4= tf.Variable(tf.zeros([1,t]), name= 'b4')
#w5= tf.get_variable("w5", [t, 1], initializer = tf.contrib.layers.xavier_initializer(seed = 7))
#b5= tf.Variable(tf.zeros([1,1]), name= 'b5')

# %%
# input data, place holders
#x = tf.placeholder("float", [None, train_x.shape[1]], name= 'x')
x = tf.placeholder("float", [None, G_scaled.shape[1]], name= 'x')
y = tf.placeholder("float", [None, 1], name= 'y')
lear_rate= tf.placeholder(tf.float32, shape=[])
# model
#z1= tf.nn.relu(tf.matmul(x,w0) + b0)
z1= tf.nn.sigmoid(tf.matmul(x,w0) + b0)
z2= tf.nn.sigmoid(tf.matmul(z1,w1) + b1)
#z3= tf.nn.relu(tf.matmul(z2,w2) + b2)
ynn= tf.matmul(z2,w2) + b2
#z5= tf.nn.relu(tf.matmul(z4,w4) + b4)
#ynn= tf.nn.relu(tf.matmul(z5,w5) + b5)
#regularizers = tf.nn.l2_loss(w0) + tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2) #+ tf.nn.l2_loss(w3)
loss= tf.losses.mean_squared_error(y, ynn)
#loss = tf.reduce_mean(loss + beta * regularizers)
#loss= tf.losses.mean_squared_error(tf.log(y + 1.00), tf.log(ynn + 1.00))
#optimizer= tf.train.AdadeltaOptimizer(lear_rate).minimize(loss)
optimizer= tf.train.GradientDescentOptimizer(lear_rate) .minimize(loss)

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
steps= 100000
batch_step= 5000
mse_vali_arra= []
mae_vali_arra= []
mse_trai_arra= []
mae_trai_arra= []
step_arra= []
batches_n= np.arange(0,G_train_scaled.shape[0],batch_step, int)
mixer= np.array(range(G_train_scaled.shape[0]))
total_cost= []
learning_rate= 0.01
ti= time.time()
for step in range(steps):
    np.random.shuffle(mixer)
    #xi= train_x[mixer,:]
    xi= G_train_scaled[mixer,:]
    yi= E_train[mixer,:]
    cost_batch= 0.0
    if step == 0:
        loss_train= sess.run(loss, feed_dict={x:G_train_scaled, y:E_train, lear_rate:learning_rate})
        print 'initial loss ', loss_train
    for n in batches_n:
        #Epred = sess.run(Enn, feed_dict={Gi:G[n:n+batch], Ei:E[n:n+batch]})
        #weight_lossb= np.square(np.subtract(Epred, E[n:n+batch]))
        _, cost= sess.run([optimizer, loss], feed_dict={x:xi[n:n+batch_step,:], y:yi[n:n+batch_step,:], lear_rate:learning_rate})#, DGi:DG[n:n+batch], Fi:F[n:n+batch]})

        #cost_batch = cost_batch + cost/numb_size
    total_cost.append(cost_batch)
    if (step % 100) == 0:
    #if (step % 50) == 0:
        Ep_train= sess.run(ynn, feed_dict={x:G_train_scaled, y:E_train, lear_rate:learning_rate})
        mse = mean_squared_error(E_train, Ep_train)
        mae= mean_absolute_error(E_train, Ep_train)
        if (step%100) == 0:
            print 'step ', step
            print("train MSE: %.4f MAE %.4f" % (mse,mae))
            print'-----------------------------------------------'
        mse_trai_arra.append(mse)
        mae_trai_arra.append(mae)
        Ep_vali= sess.run(ynn, feed_dict={x:G_vali_scaled, y:E_vali, lear_rate:learning_rate})
        mse = mean_squared_error(E_vali, Ep_vali)
        mae= mean_absolute_error(E_vali, Ep_vali)
        if (step%100) == 0:
            print("val MSE: %.6f MAE %.7f" % (mse,mae))
            print'###############################################'
        mse_vali_arra.append(mse)
        mae_vali_arra.append(mae)
        step_arra.append(step)
# Out:
# initial loss  164715.0
# step  0
# train MSE: 1867.2920 MAE 33.3837
# -----------------------------------------------
# val MSE: 1793.657294 MAE 32.8012001
# ###############################################
# step  100
# train MSE: 396.9731 MAE 12.0033
# -----------------------------------------------
# val MSE: 372.645764 MAE 11.8099848
# ###############################################
# step  200
# train MSE: 1444.5716 MAE 30.4093
# -----------------------------------------------
# val MSE: 1397.810173 MAE 30.0370866
# ###############################################
# step  300
# train MSE: 1119.4416 MAE 26.3509
# -----------------------------------------------
# val MSE: 1086.192094 MAE 26.1576450
# ###############################################
# step  400
# train MSE: 137.2883 MAE 3.7346
# -----------------------------------------------
# val MSE: 119.136556 MAE 3.6437199
# ###############################################
# step  500
# train MSE: 280.8096 MAE 11.3132
# -----------------------------------------------
# val MSE: 275.625178 MAE 11.2343332
# ###############################################
# step  600
# train MSE: 43.1779 MAE 2.5148
# -----------------------------------------------
# val MSE: 35.661283 MAE 2.4470224
# ###############################################
# step  700
# train MSE: 14.3936 MAE 1.1987
# -----------------------------------------------
# val MSE: 6.674077 MAE 1.1480434
# ###############################################
# step  800
# train MSE: 11.7705 MAE 0.9334
# -----------------------------------------------
# val MSE: 4.632651 MAE 0.8833653
# ###############################################
# step  900
# train MSE: 10.4175 MAE 0.8402
# -----------------------------------------------
# val MSE: 3.731082 MAE 0.7905770
# ###############################################
# step  1000
# train MSE: 9.2822 MAE 0.7770
# -----------------------------------------------
# val MSE: 3.138114 MAE 0.7281908
# ###############################################
# step  1100
# train MSE: 8.4168 MAE 0.7092
# -----------------------------------------------
# val MSE: 2.724889 MAE 0.6607615
# ###############################################
# step  1200
# train MSE: 7.7499 MAE 0.6546
# -----------------------------------------------
# val MSE: 2.446708 MAE 0.6128217
# ###############################################
# step  1300
# train MSE: 7.2048 MAE 0.6138
# -----------------------------------------------
# val MSE: 2.245576 MAE 0.5762540
# ###############################################
# step  1400
# train MSE: 7.0090 MAE 0.7824
# -----------------------------------------------
# val MSE: 2.357422 MAE 0.7393084
# ###############################################
# step  1500
# train MSE: 6.7740 MAE 0.8763
# -----------------------------------------------
# val MSE: 2.420354 MAE 0.8359505
# ###############################################
# step  1600
# train MSE: 6.2379 MAE 0.7661
# -----------------------------------------------
# val MSE: 2.112904 MAE 0.7303099
# ###############################################
# step  1700
# train MSE: 5.9249 MAE 0.7449
# -----------------------------------------------
# val MSE: 1.994195 MAE 0.7129373
# ###############################################
# step  1800
# train MSE: 5.5894 MAE 0.7151
# -----------------------------------------------
# val MSE: 1.801295 MAE 0.6859657
# ###############################################
# step  1900
# train MSE: 5.3572 MAE 0.7315
# -----------------------------------------------
# val MSE: 1.678780 MAE 0.7010770
# ###############################################
# step  2000
# train MSE: 5.1111 MAE 0.7548
# -----------------------------------------------
# val MSE: 1.592628 MAE 0.7257292
# ###############################################
# step  2100
# train MSE: 4.7594 MAE 0.6864
# -----------------------------------------------
# val MSE: 1.383257 MAE 0.6575954
# ###############################################
# step  2200
# train MSE: 4.3663 MAE 0.5763
# -----------------------------------------------
# val MSE: 1.122288 MAE 0.5500055
# ###############################################
# step  2300
# train MSE: 4.3050 MAE 0.6706
# -----------------------------------------------
# val MSE: 1.185624 MAE 0.6465981
# ###############################################
# step  2400
# train MSE: 4.0217 MAE 0.5788
# -----------------------------------------------
# val MSE: 1.013360 MAE 0.5560186
# ###############################################
# step  2500
# train MSE: 3.8370 MAE 0.5526
# -----------------------------------------------
# val MSE: 0.929375 MAE 0.5307777
# ###############################################
# step  2600
# train MSE: 3.7350 MAE 0.5686
# -----------------------------------------------
# val MSE: 0.916214 MAE 0.5472868
# ###############################################
# step  2700
# train MSE: 3.5427 MAE 0.5181
# -----------------------------------------------
# val MSE: 0.809321 MAE 0.4982452
# ###############################################
# step  2800
# train MSE: 3.4164 MAE 0.5074
# -----------------------------------------------
# val MSE: 0.757805 MAE 0.4879807
# ###############################################
# step  2900
# train MSE: 3.4223 MAE 0.5855
# -----------------------------------------------
# val MSE: 0.848772 MAE 0.5695657
# ###############################################
# step  3000
# train MSE: 3.2841 MAE 0.5582
# -----------------------------------------------
# val MSE: 0.782174 MAE 0.5425987
# ###############################################
# step  3100
# train MSE: 3.1472 MAE 0.5229
# -----------------------------------------------
# val MSE: 0.710932 MAE 0.5059359
# ###############################################
# step  3200
# train MSE: 2.9247 MAE 0.3787
# -----------------------------------------------
# val MSE: 0.553133 MAE 0.3605940
# ###############################################
# step  3300
# train MSE: 2.8979 MAE 0.4458
# -----------------------------------------------
# val MSE: 0.594669 MAE 0.4306759
# ###############################################
# step  3400
# train MSE: 2.7718 MAE 0.3835
# -----------------------------------------------
# val MSE: 0.533953 MAE 0.3676907
# ###############################################
# step  3500
# train MSE: 2.9085 MAE 0.5681
# -----------------------------------------------
# val MSE: 0.736079 MAE 0.5564110
# ###############################################
# step  3600
# train MSE: 2.8002 MAE 0.5414
# -----------------------------------------------
# val MSE: 0.690957 MAE 0.5300188
# ###############################################
# step  3700
# train MSE: 2.6599 MAE 0.4842
# -----------------------------------------------
# val MSE: 0.613743 MAE 0.4738624
# ###############################################
# step  3800
# train MSE: 2.5177 MAE 0.4127
# -----------------------------------------------
# val MSE: 0.522610 MAE 0.4011751
# ###############################################
# step  3900
# train MSE: 2.4279 MAE 0.3833
# -----------------------------------------------
# val MSE: 0.484322 MAE 0.3720846
# ###############################################
# step  4000
# train MSE: 2.3797 MAE 0.3975
# -----------------------------------------------
# val MSE: 0.490356 MAE 0.3874572
# ###############################################
# step  4100
# train MSE: 2.2734 MAE 0.3214
# -----------------------------------------------
# val MSE: 0.439179 MAE 0.3101856
# ###############################################
# step  4200
# train MSE: 2.2440 MAE 0.3686
# -----------------------------------------------
# val MSE: 0.453548 MAE 0.3597802
# ###############################################
# step  4300
# train MSE: 2.2026 MAE 0.3838
# -----------------------------------------------
# val MSE: 0.462921 MAE 0.3757175
# ###############################################
# step  4400
# train MSE: 2.1993 MAE 0.4331
# -----------------------------------------------
# val MSE: 0.506074 MAE 0.4262581
# ###############################################
# step  4500
# train MSE: 2.1641 MAE 0.4467
# -----------------------------------------------
# val MSE: 0.513832 MAE 0.4403957
# ###############################################
# step  4600
# train MSE: 2.0951 MAE 0.4247
# -----------------------------------------------
# val MSE: 0.491791 MAE 0.4190747
# ###############################################
# step  4700
# train MSE: 2.0288 MAE 0.3986
# -----------------------------------------------
# val MSE: 0.466713 MAE 0.3934240
# ###############################################
# step  4800
# train MSE: 1.9710 MAE 0.3832
# -----------------------------------------------
# val MSE: 0.447050 MAE 0.3776453
# ###############################################
# step  4900
# train MSE: 1.8893 MAE 0.3360
# -----------------------------------------------
# val MSE: 0.404373 MAE 0.3305787
# ###############################################
# step  5000
# train MSE: 1.9138 MAE 0.4105
# -----------------------------------------------
# val MSE: 0.472675 MAE 0.4074161
# ###############################################
# step  5100
# train MSE: 1.8650 MAE 0.3999
# -----------------------------------------------
# val MSE: 0.460628 MAE 0.3968124
# ###############################################
# step  5200
# train MSE: 1.8552 MAE 0.4216
# -----------------------------------------------
# val MSE: 0.492540 MAE 0.4194480
# ###############################################
# step  5300
# train MSE: 1.8847 MAE 0.4676
# -----------------------------------------------
# val MSE: 0.540123 MAE 0.4669582
# ###############################################
# step  5400
# train MSE: 1.8520 MAE 0.4748
# -----------------------------------------------
# val MSE: 0.538083 MAE 0.4752277
# ###############################################
# step  5500
# train MSE: 1.6801 MAE 0.3476
# -----------------------------------------------
# val MSE: 0.405546 MAE 0.3469106
# ###############################################
# step  5600
# train MSE: 1.6319 MAE 0.3331
# -----------------------------------------------
# val MSE: 0.392034 MAE 0.3332328
# ###############################################
# step  5700
# train MSE: 1.7163 MAE 0.4376
# -----------------------------------------------
# val MSE: 0.496381 MAE 0.4376266
# ###############################################
# step  5800
# train MSE: 1.5870 MAE 0.3486
# -----------------------------------------------
# val MSE: 0.422679 MAE 0.3491112
# ###############################################
# step  5900
# train MSE: 1.5705 MAE 0.3636
# -----------------------------------------------
# val MSE: 0.433615 MAE 0.3650282
# ###############################################
# step  6000
# train MSE: 1.4744 MAE 0.2746
# -----------------------------------------------
# val MSE: 0.358814 MAE 0.2745659
# ###############################################
# step  6100
# train MSE: 1.5171 MAE 0.3653
# -----------------------------------------------
# val MSE: 0.432449 MAE 0.3668090
# ###############################################
# step  6200
# train MSE: 1.5388 MAE 0.4096
# -----------------------------------------------
# val MSE: 0.484552 MAE 0.4128201
# ###############################################
# step  6300
# train MSE: 1.3873 MAE 0.2501
# -----------------------------------------------
# val MSE: 0.340003 MAE 0.2499427
# ###############################################
# step  6400
# train MSE: 1.5176 MAE 0.4351
# -----------------------------------------------
# val MSE: 0.486260 MAE 0.4382679
# ###############################################
# step  6500
# train MSE: 1.3471 MAE 0.2633
# -----------------------------------------------
# val MSE: 0.345073 MAE 0.2654153
# ###############################################
# step  6600
# train MSE: 1.4157 MAE 0.3773
# -----------------------------------------------
# val MSE: 0.427391 MAE 0.3814107
# ###############################################
# step  6700
# train MSE: 1.2945 MAE 0.2416
# -----------------------------------------------
# val MSE: 0.338537 MAE 0.2434531
# ###############################################
# step  6800
# train MSE: 1.3207 MAE 0.3122
# -----------------------------------------------
# val MSE: 0.374475 MAE 0.3157791
# ###############################################
# step  6900
# train MSE: 1.3646 MAE 0.3832
# -----------------------------------------------
# val MSE: 0.432834 MAE 0.3876640
# ###############################################
# step  7000
# train MSE: 1.3552 MAE 0.3920
# -----------------------------------------------
# val MSE: 0.440214 MAE 0.3969169
# ###############################################
# step  7100
# train MSE: 1.2505 MAE 0.2947
# -----------------------------------------------
# val MSE: 0.363254 MAE 0.2995735
# ###############################################
# step  7200
# train MSE: 1.2351 MAE 0.3085
# -----------------------------------------------
# val MSE: 0.373004 MAE 0.3136448
# ###############################################
# step  7300
# train MSE: 1.2564 MAE 0.3556
# -----------------------------------------------
# val MSE: 0.410774 MAE 0.3617746
# ###############################################
# step  7400
# train MSE: 1.1784 MAE 0.2696
# -----------------------------------------------
# val MSE: 0.350247 MAE 0.2748403
# ###############################################
# step  7500
# train MSE: 1.2242 MAE 0.3469
# -----------------------------------------------
# val MSE: 0.420712 MAE 0.3542473
# ###############################################
# step  7600
# train MSE: 1.2379 MAE 0.3796
# -----------------------------------------------
# val MSE: 0.452015 MAE 0.3884068
# ###############################################
# step  7700
# train MSE: 1.1673 MAE 0.3067
# -----------------------------------------------
# val MSE: 0.395172 MAE 0.3144810
# ###############################################
# step  7800
# train MSE: 1.1898 MAE 0.3473
# -----------------------------------------------
# val MSE: 0.440111 MAE 0.3561318
# ###############################################
# step  7900
# train MSE: 1.1428 MAE 0.3198
# -----------------------------------------------
# val MSE: 0.392455 MAE 0.3274681
# ###############################################
# step  8000
# train MSE: 1.1482 MAE 0.3495
# -----------------------------------------------
# val MSE: 0.409216 MAE 0.3580227
# ###############################################
# step  8100
# train MSE: 1.0683 MAE 0.2480
# -----------------------------------------------
# val MSE: 0.338420 MAE 0.2543449
# ###############################################
# step  8200
# train MSE: 1.1189 MAE 0.3288
# -----------------------------------------------
# val MSE: 0.412841 MAE 0.3376025
# ###############################################
# step  8300
# train MSE: 1.1156 MAE 0.3523
# -----------------------------------------------
# val MSE: 0.411996 MAE 0.3608130
# ###############################################
# step  8400
# train MSE: 1.0802 MAE 0.3213
# -----------------------------------------------
# val MSE: 0.387033 MAE 0.3290757
# ###############################################
# step  8500
# train MSE: 1.0210 MAE 0.2679
# -----------------------------------------------
# val MSE: 0.321905 MAE 0.2740492
# ###############################################
# step  8600
# train MSE: 1.1425 MAE 0.4129
# -----------------------------------------------
# val MSE: 0.477948 MAE 0.4221913
# ###############################################
# step  8700
# train MSE: 1.0455 MAE 0.3258
# -----------------------------------------------
# val MSE: 0.375307 MAE 0.3328695
# ###############################################
# step  8800
# train MSE: 1.1389 MAE 0.4189
# -----------------------------------------------
# val MSE: 0.494161 MAE 0.4271730
# ###############################################
# step  8900
# train MSE: 0.9803 MAE 0.2737
# -----------------------------------------------
# val MSE: 0.329234 MAE 0.2809741
# ###############################################
# step  9000
# train MSE: 0.9595 MAE 0.2569
# -----------------------------------------------
# val MSE: 0.316132 MAE 0.2636592
# ###############################################
# step  9100
# train MSE: 0.9928 MAE 0.3269
# -----------------------------------------------
# val MSE: 0.362868 MAE 0.3350629
# ###############################################
# step  9200
# train MSE: 0.9533 MAE 0.2796
# -----------------------------------------------
# val MSE: 0.333793 MAE 0.2875001
# ###############################################
# step  9300
# train MSE: 0.9782 MAE 0.3069
# -----------------------------------------------
# val MSE: 0.378946 MAE 0.3154071
# ###############################################
# step  9400
# train MSE: 0.9614 MAE 0.3115
# -----------------------------------------------
# val MSE: 0.367617 MAE 0.3199987
# ###############################################
# step  9500
# train MSE: 1.0192 MAE 0.3862
# -----------------------------------------------
# val MSE: 0.441740 MAE 0.3955036
# ###############################################
# step  9600
# train MSE: 0.9487 MAE 0.3268
# -----------------------------------------------
# val MSE: 0.373026 MAE 0.3357994
# ###############################################
# step  9700
# train MSE: 0.9932 MAE 0.3696
# -----------------------------------------------
# val MSE: 0.396211 MAE 0.3774688
# ###############################################
# step  9800
# train MSE: 0.9514 MAE 0.3274
# -----------------------------------------------
# val MSE: 0.365422 MAE 0.3350915
# ###############################################
# step  9900
# train MSE: 0.9862 MAE 0.3662
# -----------------------------------------------
# val MSE: 0.407369 MAE 0.3740996
# ###############################################
# step  10000
# train MSE: 0.8752 MAE 0.2637
# -----------------------------------------------
# val MSE: 0.338326 MAE 0.2728949
# ###############################################
# step  10100
# train MSE: 0.8981 MAE 0.3025
# -----------------------------------------------
# val MSE: 0.342263 MAE 0.3113556
# ###############################################
# step  10200
# train MSE: 0.9240 MAE 0.3508
# -----------------------------------------------
# val MSE: 0.408691 MAE 0.3610379
# ###############################################
# step  10300
# train MSE: 0.8746 MAE 0.3048
# -----------------------------------------------
# val MSE: 0.362357 MAE 0.3146182
# ###############################################
# step  10400
# train MSE: 0.9066 MAE 0.3370
# -----------------------------------------------
# val MSE: 0.409078 MAE 0.3474006
# ###############################################
# step  10500
# train MSE: 0.9085 MAE 0.3443
# -----------------------------------------------
# val MSE: 0.424842 MAE 0.3548363
# ###############################################
# step  10600
# train MSE: 0.8633 MAE 0.3173
# -----------------------------------------------
# val MSE: 0.379070 MAE 0.3275163
# ###############################################
# step  10700
# train MSE: 0.8501 MAE 0.3159
# -----------------------------------------------
# val MSE: 0.370642 MAE 0.3260216
# ###############################################
# step  10800
# train MSE: 0.9042 MAE 0.3483
# -----------------------------------------------
# val MSE: 0.443855 MAE 0.3594259
# ###############################################
# step  10900
# train MSE: 0.8296 MAE 0.2890
# -----------------------------------------------
# val MSE: 0.368956 MAE 0.3001102
# ###############################################
# step  11000
# train MSE: 0.7678 MAE 0.2195
# -----------------------------------------------
# val MSE: 0.303089 MAE 0.2287976
# ###############################################
# step  11100
# train MSE: 0.8400 MAE 0.3159
# -----------------------------------------------
# val MSE: 0.397153 MAE 0.3267619
# ###############################################
# step  11200
# train MSE: 0.7476 MAE 0.2024
# -----------------------------------------------
# val MSE: 0.290621 MAE 0.2121412
# ###############################################
# step  11300
# train MSE: 0.8918 MAE 0.3632
# -----------------------------------------------
# val MSE: 0.471420 MAE 0.3752264
# ###############################################
# step  11400
# train MSE: 0.7957 MAE 0.2978
# -----------------------------------------------
# val MSE: 0.368105 MAE 0.3087188
# ###############################################
# step  11500
# train MSE: 0.8526 MAE 0.3497
# -----------------------------------------------
# val MSE: 0.402552 MAE 0.3589792
# ###############################################
# step  11600
# train MSE: 0.8997 MAE 0.3834
# -----------------------------------------------
# val MSE: 0.453787 MAE 0.3926734
# ###############################################
# step  11700
# train MSE: 0.8113 MAE 0.3219
# -----------------------------------------------
# val MSE: 0.376226 MAE 0.3314483
# ###############################################
# step  11800
# train MSE: 0.7543 MAE 0.2500
# -----------------------------------------------
# val MSE: 0.324886 MAE 0.2591212
# ###############################################
# step  11900
# train MSE: 0.7729 MAE 0.2860
# -----------------------------------------------
# val MSE: 0.350562 MAE 0.2960562
# ###############################################
# step  12000
# train MSE: 0.7794 MAE 0.3074
# -----------------------------------------------
# val MSE: 0.360057 MAE 0.3164404
# ###############################################
# step  12100
# train MSE: 0.8092 MAE 0.3421
# -----------------------------------------------
# val MSE: 0.397357 MAE 0.3521368
# ###############################################
# step  12200
# train MSE: 0.7891 MAE 0.3263
# -----------------------------------------------
# val MSE: 0.383553 MAE 0.3360548
# ###############################################
# step  12300
# train MSE: 0.8797 MAE 0.3683
# -----------------------------------------------
# val MSE: 0.474104 MAE 0.3766226
# ###############################################
# step  12400
# train MSE: 0.8041 MAE 0.3250
# -----------------------------------------------
# val MSE: 0.405115 MAE 0.3332071
# ###############################################
# step  12500
# train MSE: 0.6899 MAE 0.2245
# -----------------------------------------------
# val MSE: 0.327315 MAE 0.2360088
# ###############################################
# step  12600
# train MSE: 0.7121 MAE 0.2622
# -----------------------------------------------
# val MSE: 0.331983 MAE 0.2719740
# ###############################################
# step  12700
# train MSE: 0.8755 MAE 0.3835
# -----------------------------------------------
# val MSE: 0.492722 MAE 0.3917100
# ###############################################
# step  12800
# train MSE: 0.7524 MAE 0.3285
# -----------------------------------------------
# val MSE: 0.384603 MAE 0.3390038
# ###############################################
# step  12900
# train MSE: 0.6680 MAE 0.2287
# -----------------------------------------------
# val MSE: 0.310961 MAE 0.2393774
# ###############################################
# step  13000
# train MSE: 0.7200 MAE 0.2975
# -----------------------------------------------
# val MSE: 0.398456 MAE 0.3103572
# ###############################################
# step  13100
# train MSE: 0.7142 MAE 0.2989
# -----------------------------------------------
# val MSE: 0.396972 MAE 0.3115931
# ###############################################
# step  13200
# train MSE: 0.7002 MAE 0.2777
# -----------------------------------------------
# val MSE: 0.392633 MAE 0.2912051
# ###############################################
# step  13300
# train MSE: 0.7848 MAE 0.4047
# -----------------------------------------------
# val MSE: 0.484972 MAE 0.4163972
# ###############################################
# step  13400
# train MSE: 0.7150 MAE 0.3173
# -----------------------------------------------
# val MSE: 0.423663 MAE 0.3309599
# ###############################################
# step  13500
# train MSE: 0.6824 MAE 0.2875
# -----------------------------------------------
# val MSE: 0.393159 MAE 0.3010499
# ###############################################
# step  13600
# train MSE: 0.6707 MAE 0.2627
# -----------------------------------------------
# val MSE: 0.356829 MAE 0.2733303
# ###############################################
# step  13700
# train MSE: 0.5912 MAE 0.1863
# -----------------------------------------------
# val MSE: 0.301450 MAE 0.1993906
# ###############################################
# step  13800
# train MSE: 0.6222 MAE 0.2401
# -----------------------------------------------
# val MSE: 0.346342 MAE 0.2539987
# ###############################################
# step  13900
# train MSE: 0.6873 MAE 0.2993
# -----------------------------------------------
# val MSE: 0.426550 MAE 0.3135635
# ###############################################
# step  14000
# train MSE: 0.7571 MAE 0.3643
# -----------------------------------------------
# val MSE: 0.511363 MAE 0.3789979
# ###############################################
# step  14100
# train MSE: 0.5842 MAE 0.2127
# -----------------------------------------------
# val MSE: 0.322563 MAE 0.2265376
# ###############################################
# step  14200
# train MSE: 0.6724 MAE 0.3026
# -----------------------------------------------
# val MSE: 0.428586 MAE 0.3175156
# ###############################################
# step  14300
# train MSE: 0.6370 MAE 0.2616
# -----------------------------------------------
# val MSE: 0.397484 MAE 0.2764020
# ###############################################
# step  14400
# train MSE: 0.6659 MAE 0.2975
# -----------------------------------------------
# val MSE: 0.434679 MAE 0.3118714
# ###############################################
# step  14500
# train MSE: 0.6464 MAE 0.2814
# -----------------------------------------------
# val MSE: 0.420868 MAE 0.2960389
# ###############################################
# step  14600
# train MSE: 0.6217 MAE 0.2648
# -----------------------------------------------
# val MSE: 0.365115 MAE 0.2767722
# ###############################################
# step  14700
# train MSE: 0.6201 MAE 0.2921
# -----------------------------------------------
# val MSE: 0.370607 MAE 0.3046310
# ###############################################
# step  14800
# train MSE: 0.6786 MAE 0.3223
# -----------------------------------------------
# val MSE: 0.430957 MAE 0.3338601
# ###############################################
# step  14900
# train MSE: 0.6961 MAE 0.3365
# -----------------------------------------------
# val MSE: 0.452233 MAE 0.3486833
# ###############################################
# step  15000
# train MSE: 0.6007 MAE 0.2782
# -----------------------------------------------
# val MSE: 0.364029 MAE 0.2908876
# ###############################################
# step  15100
# train MSE: 0.6759 MAE 0.3450
# -----------------------------------------------
# val MSE: 0.441688 MAE 0.3567913
# ###############################################
# step  15200
# train MSE: 0.7544 MAE 0.3541
# -----------------------------------------------
# val MSE: 0.518655 MAE 0.3645662
# ###############################################
# step  15300
# train MSE: 0.6743 MAE 0.3233
# -----------------------------------------------
# val MSE: 0.441850 MAE 0.3334723
# ###############################################
# step  15400
# train MSE: 0.5391 MAE 0.2330
# -----------------------------------------------
# val MSE: 0.320118 MAE 0.2452479
# ###############################################
# step  15500
# train MSE: 0.6233 MAE 0.2987
# -----------------------------------------------
# val MSE: 0.403090 MAE 0.3111292
# ###############################################
# step  15600
# train MSE: 0.6330 MAE 0.2945
# -----------------------------------------------
# val MSE: 0.417720 MAE 0.3065471
# ###############################################
# step  15700
# train MSE: 0.4942 MAE 0.1948
# -----------------------------------------------
# val MSE: 0.288331 MAE 0.2075676
# ###############################################
# step  15800
# train MSE: 0.6235 MAE 0.3175
# -----------------------------------------------
# val MSE: 0.413346 MAE 0.3295986
# ###############################################
# step  15900
# train MSE: 0.7138 MAE 0.3415
# -----------------------------------------------
# val MSE: 0.505370 MAE 0.3527205
# ###############################################
# step  16000
# train MSE: 0.5570 MAE 0.2530
# -----------------------------------------------
# val MSE: 0.355677 MAE 0.2653563
# ###############################################
# step  16100
# train MSE: 0.6114 MAE 0.2985
# -----------------------------------------------
# val MSE: 0.410729 MAE 0.3103290
# ###############################################
# step  16200
# train MSE: 0.6826 MAE 0.3560
# -----------------------------------------------
# val MSE: 0.485300 MAE 0.3672703
# ###############################################
# step  16300
# train MSE: 0.6048 MAE 0.3060
# -----------------------------------------------
# val MSE: 0.411100 MAE 0.3179032
# ###############################################
# step  16400
# train MSE: 0.5413 MAE 0.2572
# -----------------------------------------------
# val MSE: 0.351866 MAE 0.2694807
# ###############################################
# step  16500
# train MSE: 0.6212 MAE 0.3099
# -----------------------------------------------
# val MSE: 0.434761 MAE 0.3221721
# ###############################################
# step  16600
# train MSE: 0.6369 MAE 0.3493
# -----------------------------------------------
# val MSE: 0.453646 MAE 0.3617098
# ###############################################
# step  16700
# train MSE: 0.5729 MAE 0.3391
# -----------------------------------------------
# val MSE: 0.390375 MAE 0.3504530
# ###############################################
# step  16800
# train MSE: 0.5532 MAE 0.2842
# -----------------------------------------------
# val MSE: 0.376554 MAE 0.2965382
# ###############################################
# step  16900
# train MSE: 0.5699 MAE 0.2903
# -----------------------------------------------
# val MSE: 0.395799 MAE 0.3029715
# ###############################################
# step  17000
# train MSE: 0.5211 MAE 0.2631
# -----------------------------------------------
# val MSE: 0.349480 MAE 0.2753413
# ###############################################
# step  17100
# train MSE: 0.5836 MAE 0.2929
# -----------------------------------------------
# val MSE: 0.414096 MAE 0.3051900
# ###############################################
# step  17200
# train MSE: 0.5575 MAE 0.3044
# -----------------------------------------------
# val MSE: 0.392738 MAE 0.3172167
# ###############################################
# step  17300
# train MSE: 0.6825 MAE 0.3688
# -----------------------------------------------
# val MSE: 0.517420 MAE 0.3808524
# ###############################################
# step  17400
# train MSE: 0.4926 MAE 0.2501
# -----------------------------------------------
# val MSE: 0.332620 MAE 0.2627937
# ###############################################
# step  17500
# train MSE: 0.6590 MAE 0.3699
# -----------------------------------------------
# val MSE: 0.498593 MAE 0.3818695
# ###############################################
# step  17600
# train MSE: 0.5928 MAE 0.3260
# -----------------------------------------------
# val MSE: 0.435335 MAE 0.3378439
# ###############################################
# step  17700
# train MSE: 0.5030 MAE 0.2735
# -----------------------------------------------
# val MSE: 0.352935 MAE 0.2865571
# ###############################################
# step  17800
# train MSE: 0.4635 MAE 0.2205
# -----------------------------------------------
# val MSE: 0.316769 MAE 0.2337686
# ###############################################
# step  17900
# train MSE: 0.4891 MAE 0.2746
# -----------------------------------------------
# val MSE: 0.343307 MAE 0.2873950
# ###############################################
# step  18000
# train MSE: 0.5659 MAE 0.3133
# -----------------------------------------------
# val MSE: 0.420670 MAE 0.3265969
# ###############################################
# step  18100
# train MSE: 0.5031 MAE 0.2693
# -----------------------------------------------
# val MSE: 0.362316 MAE 0.2827702
# ###############################################
# step  18200
# train MSE: 0.5359 MAE 0.2894
# -----------------------------------------------
# val MSE: 0.396191 MAE 0.3026109
# ###############################################
# step  18300
# train MSE: 0.7743 MAE 0.4032
# -----------------------------------------------
# val MSE: 0.633231 MAE 0.4147838
# ###############################################
# step  18400
# train MSE: 0.4577 MAE 0.2349
# -----------------------------------------------
# val MSE: 0.323038 MAE 0.2474182
# ###############################################
# step  18500
# train MSE: 0.4720 MAE 0.2452
# -----------------------------------------------
# val MSE: 0.369254 MAE 0.2614066
# ###############################################
# step  18600
# train MSE: 0.5752 MAE 0.3326
# -----------------------------------------------
# val MSE: 0.484802 MAE 0.3489286
# ###############################################
# step  18700
# train MSE: 0.4262 MAE 0.2232
# -----------------------------------------------
# val MSE: 0.323502 MAE 0.2391616
# ###############################################
# step  18800
# train MSE: 0.4636 MAE 0.2530
# -----------------------------------------------
# val MSE: 0.369427 MAE 0.2694027
# ###############################################
# step  18900
# train MSE: 0.4949 MAE 0.2737
# -----------------------------------------------
# val MSE: 0.405739 MAE 0.2896201
# ###############################################
# step  19000
# train MSE: 0.4223 MAE 0.2143
# -----------------------------------------------
# val MSE: 0.323874 MAE 0.2304523
# ###############################################
# step  19100
# train MSE: 0.4294 MAE 0.2309
# -----------------------------------------------
# val MSE: 0.336272 MAE 0.2468864
# ###############################################
# step  19200
# train MSE: 0.4731 MAE 0.2568
# -----------------------------------------------
# val MSE: 0.387404 MAE 0.2730767
# ###############################################
# step  19300
# train MSE: 0.6607 MAE 0.3549
# -----------------------------------------------
# val MSE: 0.595629 MAE 0.3720090
# ###############################################
# step  19400
# train MSE: 0.5879 MAE 0.3604
# -----------------------------------------------
# val MSE: 0.517269 MAE 0.3759012
# ###############################################
# step  19500
# train MSE: 0.4569 MAE 0.2618
# -----------------------------------------------
# val MSE: 0.375015 MAE 0.2778061
# ###############################################
# step  19600
# train MSE: 0.5491 MAE 0.3085
# -----------------------------------------------
# val MSE: 0.480591 MAE 0.3248110
# ###############################################
# step  19700
# train MSE: 0.5148 MAE 0.3011
# -----------------------------------------------
# val MSE: 0.443332 MAE 0.3178374
# ###############################################
# step  19800
# train MSE: 0.5499 MAE 0.3407
# -----------------------------------------------
# val MSE: 0.484220 MAE 0.3566266
# ###############################################
# step  19900
# train MSE: 0.4764 MAE 0.2795
# -----------------------------------------------
# val MSE: 0.404953 MAE 0.2960654
# ###############################################
# step  20000
# train MSE: 0.4558 MAE 0.2596
# -----------------------------------------------
# val MSE: 0.354382 MAE 0.2743783
# ###############################################
# step  20100
# train MSE: 0.5777 MAE 0.3082
# -----------------------------------------------
# val MSE: 0.473199 MAE 0.3214377
# ###############################################
# step  20200
# train MSE: 0.4940 MAE 0.2724
# -----------------------------------------------
# val MSE: 0.391831 MAE 0.2853447
# ###############################################
# step  20300
# train MSE: 0.5137 MAE 0.2829
# -----------------------------------------------
# val MSE: 0.414367 MAE 0.2958324
# ###############################################
# step  20400
# train MSE: 0.4761 MAE 0.2715
# -----------------------------------------------
# val MSE: 0.379386 MAE 0.2853224
# ###############################################
# step  20500
# train MSE: 0.6304 MAE 0.3556
# -----------------------------------------------
# val MSE: 0.584506 MAE 0.3728181
# ###############################################
# step  20600
# train MSE: 0.4917 MAE 0.2652
# -----------------------------------------------
# val MSE: 0.396975 MAE 0.2789778
# ###############################################
# step  20700
# train MSE: 0.4315 MAE 0.2464
# -----------------------------------------------
# val MSE: 0.338562 MAE 0.2598368
# ###############################################
# step  20800
# train MSE: 0.5115 MAE 0.2941
# -----------------------------------------------
# val MSE: 0.421165 MAE 0.3087789
# ###############################################
# step  20900
# train MSE: 0.4677 MAE 0.2471
# -----------------------------------------------
# val MSE: 0.378468 MAE 0.2610210
# ###############################################
# step  21000
# train MSE: 0.6799 MAE 0.3389
# -----------------------------------------------
# val MSE: 0.591663 MAE 0.3520470
# ###############################################
# step  21100
# train MSE: 0.4451 MAE 0.2602
# -----------------------------------------------
# val MSE: 0.355726 MAE 0.2734108
# ###############################################
# step  21200
# train MSE: 0.4203 MAE 0.2511
# -----------------------------------------------
# val MSE: 0.337010 MAE 0.2661151
# ###############################################
# step  21300
# train MSE: 0.6317 MAE 0.3437
# -----------------------------------------------
# val MSE: 0.544456 MAE 0.3563289
# ###############################################
# step  21400
# train MSE: 0.4945 MAE 0.2795
# -----------------------------------------------
# val MSE: 0.409731 MAE 0.2928672
# ###############################################
# step  21500
# train MSE: 0.6068 MAE 0.3415
# -----------------------------------------------
# val MSE: 0.522238 MAE 0.3538962
# ###############################################
# step  21600
# train MSE: 0.3776 MAE 0.2189
# -----------------------------------------------
# val MSE: 0.299070 MAE 0.2330662
# ###############################################
# step  21700
# train MSE: 0.3550 MAE 0.1989
# -----------------------------------------------
# val MSE: 0.276821 MAE 0.2130841
# ###############################################
# step  21800
# train MSE: 0.4691 MAE 0.2915
# -----------------------------------------------
# val MSE: 0.427571 MAE 0.3072338
# ###############################################
# step  21900
# train MSE: 0.5691 MAE 0.3036
# -----------------------------------------------
# val MSE: 0.537328 MAE 0.3201906
# ###############################################
# step  22000
# train MSE: 0.3322 MAE 0.1803
# -----------------------------------------------
# val MSE: 0.274267 MAE 0.1958449
# ###############################################
# step  22100
# train MSE: 0.4255 MAE 0.2655
# -----------------------------------------------
# val MSE: 0.381545 MAE 0.2812918
# ###############################################
# step  22200
# train MSE: 0.3439 MAE 0.2122
# -----------------------------------------------
# val MSE: 0.291278 MAE 0.2281439
# ###############################################
# step  22300
# train MSE: 0.5681 MAE 0.3090
# -----------------------------------------------
# val MSE: 0.538715 MAE 0.3255560
# ###############################################
# step  22400
# train MSE: 0.4247 MAE 0.2863
# -----------------------------------------------
# val MSE: 0.382005 MAE 0.3022959
# ###############################################
# step  22500
# train MSE: 0.4361 MAE 0.2672
# -----------------------------------------------
# val MSE: 0.398280 MAE 0.2830818
# ###############################################
# step  22600
# train MSE: 0.4852 MAE 0.2703
# -----------------------------------------------
# val MSE: 0.451455 MAE 0.2870288
# ###############################################
# step  22700
# train MSE: 0.3820 MAE 0.2649
# -----------------------------------------------
# val MSE: 0.336824 MAE 0.2804200
# ###############################################
# step  22800
# train MSE: 0.3458 MAE 0.2071
# -----------------------------------------------
# val MSE: 0.297831 MAE 0.2228861
# ###############################################
# step  22900
# train MSE: 0.4857 MAE 0.2841
# -----------------------------------------------
# val MSE: 0.454743 MAE 0.3001369
# ###############################################
# step  23000
# train MSE: 0.4052 MAE 0.2255
# -----------------------------------------------
# val MSE: 0.367342 MAE 0.2418022
# ###############################################
# step  23100
# train MSE: 0.4866 MAE 0.2936
# -----------------------------------------------
# val MSE: 0.460171 MAE 0.3095513
# ###############################################
# step  23200
# train MSE: 0.4003 MAE 0.2453
# -----------------------------------------------
# val MSE: 0.363394 MAE 0.2610724
# ###############################################
# step  23300
# train MSE: 0.3740 MAE 0.2240
# -----------------------------------------------
# val MSE: 0.335958 MAE 0.2395692
# ###############################################
# step  23400
# train MSE: 0.3822 MAE 0.2386
# -----------------------------------------------
# val MSE: 0.345692 MAE 0.2543166
# ###############################################
# step  23500
# train MSE: 0.4319 MAE 0.2624
# -----------------------------------------------
# val MSE: 0.402111 MAE 0.2783775
# ###############################################
# step  23600
# train MSE: 0.4533 MAE 0.2677
# -----------------------------------------------
# val MSE: 0.424871 MAE 0.2839874
# ###############################################
# step  23700
# train MSE: 0.4213 MAE 0.2577
# -----------------------------------------------
# val MSE: 0.391406 MAE 0.2737146
# ###############################################

# %%
learning_rate= 0.005
ti= time.time()
for step in range(steps):
    np.random.shuffle(mixer)
    #xi= train_x[mixer,:]
    xi= G_train_scaled[mixer,:]
    yi= E_train[mixer,:]
    cost_batch= 0.0
    if step == 0:
        loss_train= sess.run(loss, feed_dict={x:G_train_scaled, y:E_train, lear_rate:learning_rate})
        print 'initial loss ', loss_train
    for n in batches_n:
        #Epred = sess.run(Enn, feed_dict={Gi:G[n:n+batch], Ei:E[n:n+batch]})
        #weight_lossb= np.square(np.subtract(Epred, E[n:n+batch]))
        _, cost= sess.run([optimizer, loss], feed_dict={x:xi[n:n+batch_step,:], y:yi[n:n+batch_step,:], lear_rate:learning_rate})#, DGi:DG[n:n+batch], Fi:F[n:n+batch]})

        #cost_batch = cost_batch + cost/numb_size
    total_cost.append(cost_batch)
    if (step % 100) == 0:
    #if (step % 50) == 0:
        Ep_train= sess.run(ynn, feed_dict={x:G_train_scaled, y:E_train, lear_rate:learning_rate})
        mse = mean_squared_error(E_train, Ep_train)
        mae= mean_absolute_error(E_train, Ep_train)
        if (step%100) == 0:
            print 'step ', step
            print("train MSE: %.4f MAE %.4f" % (mse,mae))
            print'-----------------------------------------------'
        mse_trai_arra.append(mse)
        mae_trai_arra.append(mae)
        Ep_vali= sess.run(ynn, feed_dict={x:G_vali_scaled, y:E_vali, lear_rate:learning_rate})
        mse = mean_squared_error(E_vali, Ep_vali)
        mae= mean_absolute_error(E_vali, Ep_vali)
        if (step%100) == 0:
            print("val MSE: %.4f MAE %.4f" % (mse,mae))
            print'###############################################'
        mse_vali_arra.append(mse)
        mae_vali_arra.append(mae)
        step_arra.append(step)

# %%
print 'name'
# Out:
# name

# %%
Ep= sess.run(ynn, feed_dict={x:g_st})

# %%
Et= np.squeeze(enert)

# %%
mse = mean_squared_error(Et[trai_id], Ep[trai_id])
mae= mean_absolute_error(Et[trai_id], Ep[trai_id])
print("val MSE: %.7f MAE %.5f" % (mse,mae))
mse = mean_squared_error(Et[vali_id], Ep[vali_id])
mae= mean_absolute_error(Et[vali_id], Ep[vali_id])
print("val MSE: %.7f MAE %.5f" % (mse,mae))
# Out:
# val MSE: 0.0398865 MAE 0.06116
# val MSE: 0.3123870 MAE 0.08459

# %%
np.save('E_pred_%s_%s_%s'%(feat_type,numb_feat,exp_name), Ep)
np.save('E_targ_%s_%s_%s'%(feat_type,numb_feat,exp_name), Et)
np.save('trai_id_%s_%s_%s'%(feat_type,numb_feat,exp_name), trai_id)
np.save('vali_id_%s_%s_%s'%(feat_type,numb_feat,exp_name), vali_id)

# %%
plt.plot(Et[trai_id], Ep[trai_id], '*g', Et[trai_id], Et[trai_id], '*b')
plt.show()

plt.plot(Et[vali_id], Ep[vali_id], '*g', Et[vali_id], Et[vali_id], '*b')
plt.show()

# %%
print 'loss_trai->', loss_train, '  loss_vali->', loss_vali
# Out:
# loss_trai-> 0.0794464   loss_vali-> 0.0894807

# %%
print np.min(vali_arra)
print np.min(trai_arra)
# Out:
# 0.0828708
# 0.0717404

# %%
print tf-ti
# Out:
# 18110.9055598

# %%
print len(trai_arra)
print len(vali_arra)
print len(step_arra)
plt.plot(step_arra[40:], trai_arra[40:], 'b', step_arra[40:], vali_arra[40:], 'r')
plt.show()
# Out:
# 2000
# 2000
# 2000

# %%
E_train_nn= sess.run(ynn, feed_dict={x:G_train_scaled, y:E_train})

plt.plot(E_train_nn, E_train, '*b', E_train, E_train, '*r')
plt.show()

# %%
diff_train= np.abs(np.subtract(E_train_nn, E_train))
print np.max(diff_train)
print np.min(diff_train)
diff_train_aver= np.average(diff_train)
print diff_train_aver
# Out:
# 1.42552285937
# 2.55390625625e-05
# 0.204786959756

# %%
n, bins, patches = plt.hist(diff_train, 300, facecolor='g', alpha=0.75)
plt.axis([0.0, 0.7, 0, 100])
plt.show()

# %%
n, bins, patches = plt.hist(diff_train, 300, facecolor='g', alpha=0.75)
plt.axis([0.0, 1.0, 0, 1000])
plt.show()

# %%
print n[160]
print bins[160]
# Out:
# 4.0
# 0.760290776563

# %%
E_vali_nn= sess.run(ynn, feed_dict={x:G_vali_scaled, y:E_vali})

plt.plot(E_vali_nn, E_vali, '*b', E_vali, E_vali, '*r')
plt.show()

# %%
diff_vali= np.abs(np.subtract(E_vali_nn, E_vali))
print np.max(diff_vali)
print np.min(diff_vali)
diff_vali_aver= np.average(diff_vali)
print diff_vali_aver

n, bins, patches = plt.hist(diff_vali, 300, facecolor='g', alpha=0.75)
plt.axis([0.0, 3.4, 0, 100])
plt.show()
# Out:
# 1.21361501563
# 6.8906249453e-06
# 0.219804994049

# %%
np.save('../analysis/diff_vali_nn_l20_k20_q1_X_oni_48', diff_vali)

# %%
E_nn= sess.run(ynn, feed_dict={x:G_scaled, y:E})
E_nn_vali=sess.run(ynn, feed_dict={x:G_scaled[struid_vali], y:E})
E_nn_train=sess.run(ynn, feed_dict={x:G_scaled[struid_train], y:E})

np.save('E_nn_vali_C10_t_500_F2_I_gauss_48_2', E_nn_vali)
np.save('E_vali_C10_t_500_F2_I_gauss_48_2', E[struid_vali])
np.save('stru_vali_C10_t_500_F2_I_gauss_48_2', struid_vali)

np.save('E_nn_train_C10_t_500_F2_I_gauss_48_2', E_nn_train)
np.save('E_train_C10_t_500_F2_I_gauss_48_2', E[struid_train])
np.save('stru_train_C10_t_500_F2_I_gauss_48_2', struid_train)

# %%
E_nn= sess.run(ynn, feed_dict={x:G_scaled, y:E})
E_nn_vali=sess.run(ynn, feed_dict={x:G_scaled[struid_vali], y:E})
E_nn_train=sess.run(ynn, feed_dict={x:G_scaled[struid_train], y:E})

np.save('E_nn_vali_C10_t_500_F2_I_gauss_48_1', E_nn_vali)
np.save('E_vali_C10_t_500_F2_I_gauss_48_1', E[struid_vali])
np.save('stru_vali_C10_t_500_F2_I_gauss_48_1', struid_vali)

np.save('E_nn_train_C10_t_500_F2_I_gauss_48_1', E_nn_train)
np.save('E_train_C10_t_500_F2_I_gauss_48_1', E[struid_train])
np.save('stru_train_C10_t_500_F2_I_gauss_48_1', struid_train)
